# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
config = {'mask_dropout': True, 'separate_shuffler': False, 'soft_fake': False, 'soft_valid': True}

# %cd '/content/drive/My Drive/Workspace Riset Tata/Python workspace/thesis'
import config_16x15_seq
# %cd '/content/drive/My Drive/Workspace Riset Tata/Python workspace/thesis/config_16x15_seq'

import json

with open('config.json', 'w') as f:
    json.dump(config, f)

import os
import pprint
import tensorflow as tf

if 'COLAB_TPU_ADDR' not in os.environ:
    device_name = tf.test.gpu_device_name()
    if device_name != '/device:GPU:0':
        print('ERROR!')
    else:
        print('Found GPU at: {}'.format(device_name))
else:
    tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
    print('TPU address is', tpu_address)
    with tf.Session(tpu_address) as session:
        devices = session.list_devices()
        print('TPU devices:')
        pprint.pprint(devices)

# %run ./test7.py
# Out:
# /content/drive/My Drive/Workspace Riset Tata/Python workspace/thesis
# /content/drive/My Drive/Workspace Riset Tata/Python workspace/thesis/config_16x15_seq
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Found GPU at: /device:GPU:0
# Using TensorFlow backend.
# WARNING:tensorflow:From /content/drive/My Drive/Workspace Riset Tata/Python workspace/thesis/config_16x15_seq/helper.py:54: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# ...

# %%
gan.save('thesis_0_0.h5')
generator.save('thesis_0_0_gen.h5')
discriminator.save('thesis_0_0_dis.h5')
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/network.py:883: UserWarning: Layer bidirectional_1 was passed non-serializable keyword arguments: {'mask': <tf.Tensor 'lambda_5/Squeeze:0' shape=(?, ?) dtype=float32>}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '

# %%
set_model('thesis_0_0.h5', [PHI_meas, freq, d])

# %%
plot_result(6, True, 'calibrated')
plot_result(5, True, 'calibrated')
plot_result(4, True, 'calibrated')
plot_result(3, True, 'calibrated')
plot_result(2, True, 'calibrated')
plot_result(1, True, 'calibrated')
plot_result(0, True, 'calibrated')

# %%
# %cd '/content/drive/My Drive/Workspace Riset Tata/Python workspace/thesis'
# set_model('model34log.h5', [PHI_meas, freq, d])
# Out:
# /content/drive/My Drive/Workspace Riset Tata/Python workspace/thesis
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-14-caf9ba05361a> in <module>()
#       1 get_ipython().magic("cd '/content/drive/My Drive/Workspace Riset Tata/Python workspace/thesis'")
# ----> 2 set_model('model34log.h5', [PHI_meas, freq, d])
#
# /content/drive/My Drive/Workspace Riset Tata/Python workspace/thesis/config_16x15_seq/helper.py in set_model(param_model, param_input, sel, print_summary)
#     260     if param_model is not model:
#     261         if isinstance(param_model, str):
# --> 262             model = load_model(param_model, custom_objects=custom_objects)
#     263         else:
#     264             model = param_model
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py in load_wrapper(*args, **kwargs)
#     456                 os.remove(tmp_filepath)
# ...

# %%
# %cd '/content/drive/My Drive/Workspace Riset Tata/Python workspace/thesis'
import config_16x15_seq
# %cd '/content/drive/My Drive/Workspace Riset Tata/Python workspace/thesis/config_16x15_seq'
# %run ./test8.py
# Out:
# /content/drive/My Drive/Workspace Riset Tata/Python workspace/thesis
# /content/drive/My Drive/Workspace Riset Tata/Python workspace/thesis/config_16x15_seq
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /content/drive/My Drive/Workspace Riset Tata/Python workspace/thesis/config_16x15_seq/test8.py in <module>()
#       6
#       7
# ----> 8 model = primary_net()
#       9 loss = 'mse'
#      10 metrics = ['mae', 'mse', 'mape', 'msle', 'logcosh', 'cosine']
#
# /content/drive/My Drive/Workspace Riset Tata/Python workspace/thesis/config_16x15_seq/builder.py in primary_net()
#     706     # contrast1, contrast2 = contrast_net([input1d_mag, input1d_phs], n_out=2)
#     707     # background1, background2 = background_net([input1d_mag, input1d_phs], n_out=2)
# --> 708     contrasts, backgrounds = background_and_contrast_net([input_seq] + inputs[1:], input_mask, n_out=2)
# ...
